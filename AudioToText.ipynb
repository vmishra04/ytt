# %%
from __future__ import unicode_literals
import youtube_dl
import speech_recognition as sr
import csv
import os
from datetime import datetime
import pandas as pd

# %%
"""
@Title: Youtube to Text.
@Author: devazm.
@Date: 10/25/2018.
"""
class ytt():
    def __init__(self):
        self.ids = []
        self.read_csv('news_politics_caption.csv')
        self.df= pd.DataFrame()
        if not os.path.exists('txts'):
            os.makedirs('txts')
        
    def read_csv(self, csvpath):
        """with open(csvpath, 'r', newline='') as csvfile:
            csvreader = csv.DictReader(csvfile, dialect='excel')
            for row in csvreader:
                self.ids.append(row['id'])
            """
        self.df = pd.read_csv(csvpath, nrows=20)
        self.df = self.df[self.df['subtitle'].isnull()]
        self.ids = self.df['id']
        
    def get_audio(self, vid):
        ydl_opts = {
            'format': 'bestaudio',
            'postprocessors': [{
                'key': 'FFmpegExtractAudio',
                'preferredcodec': 'flac',
                'preferredquality': '32',
            }],
            'outtmpl': '%(id)s.%(etx)s',
            'quiet': True
        }
        with youtube_dl.YoutubeDL(ydl_opts) as ydl:
            ydl.download(['https://www.youtube.com/watch?v={}'.format(vid)])

    def get_text(self, vid):
        r = sr.Recognizer()
        audiofile = sr.AudioFile(vid + '.flac')
        with audiofile as source:
            audio = r.record(source)
        text_string = str(r.recognize_sphinx(audio))
        with open('txts/{}.txt'.format(vid), 'w') as txtfile:
            txtfile.write(text_string) #recognize_google
        self.df.loc[self.df['id'] == vid, 'subtitle'] = text_string
        
    def start(self):
        i = 0
        for id in self.ids:
            i += 1
            if os.path.exists('txts/{}.txt'.format(id)) or os.path.exists('{}.NA'.format(id)):
                continue
            try:
                print('{}) {}\n{} - Downloading Audio ...'.format(str(i), str(id), datetime.now().strftime('%H:%M:%S')))
                self.get_audio(id)
                print('{} - Download Completed.\n{} - Processing Audio File ...'.format(datetime.now().strftime('%H:%M:%S'), datetime.now().strftime('%H:%M:%S')))
                self.get_text(id)
                print('{} - Processing Completed'.format(datetime.now().strftime('%H:%M:%S')))
                if os.path.exists('{}.flac'.format(id)):
                    os.remove('{}.flac'.format(id))
            except Exception as e: 
                print(e)
                print('Error!')
        self.df.to_csv("audio_to_text_df.csv")
project = ytt()
project.start()
# Out:
# 1) FNryYNNqStY
# 14:57:59 - Downloading Audio ...
# 14:58:03 - Download Completed.
# 14:58:03 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 2) aXxu8SBeBKU
# 14:58:04 - Downloading Audio ...
# 14:58:07 - Download Completed.
# 14:58:07 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 3) 0_n4PAkNYXo
# 14:58:08 - Downloading Audio ...
# 14:58:10 - Download Completed.
# 14:58:10 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 4) zKgN2G9d0dc
# 14:58:10 - Downloading Audio ...
# 14:58:15 - Download Completed.
# 14:58:15 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 5) eg9foFo6vHk
# 14:58:15 - Downloading Audio ...
# 14:58:18 - Download Completed.
# 14:58:18 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 6) EBNtlUqmVso
# 14:58:18 - Downloading Audio ...
# 14:58:25 - Download Completed.
# 14:58:25 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 7) a25ERxBKF44
# 14:58:25 - Downloading Audio ...
# 14:58:31 - Download Completed.
# 14:58:31 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 8) rpf4J2ksy5w
# 14:58:33 - Downloading Audio ...
# 14:58:36 - Download Completed.
# 14:58:36 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 9) KO457SWyRbw
# 14:58:37 - Downloading Audio ...
# 14:58:43 - Download Completed.
# 14:58:43 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 10) JnWL9CouvbA
# 14:58:44 - Downloading Audio ...
# 14:58:47 - Download Completed.
# 14:58:47 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 11) 2uPj7SzmSdU
# 14:58:47 - Downloading Audio ...
# 14:58:51 - Download Completed.
# 14:58:51 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 12) _hXG6cWhs50
# 14:58:52 - Downloading Audio ...
# 14:58:54 - Download Completed.
# 14:58:54 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 13) 3gtywPE9BpQ
# 14:58:54 - Downloading Audio ...
# 14:58:59 - Download Completed.
# 14:58:59 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 14) iY9C5oj9pSM
# 14:59:00 - Downloading Audio ...
# 14:59:03 - Download Completed.
# 14:59:03 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# 15) J4BlEB9sYIU
# 14:59:03 - Downloading Audio ...
# 14:59:08 - Download Completed.
# 14:59:08 - Processing Audio File ...
# missing PocketSphinx module: ensure that PocketSphinx is set up correctly.
# Error!
# Empty DataFrame
# Columns: []
# Index: []
